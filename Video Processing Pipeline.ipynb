# %%
import numpy as np
import cv2
import glob
import matplotlib
import matplotlib.pyplot as plt

from src.binary_lane_filter import apply_road_lane_binary_filter
from src.lib import abs_sobel_thresh, abs_thresh
from src.curvature import estimate_lane_curve_radius_m

from src.warp import ImageWarp
from src.line import TrafficLine, find_line_position
from src.visualisation import window_corners, color_window_pixels

from src.pipeline import create_image_processor

process_image = create_image_processor()

# %matplotlib qt
# %matplotlib inline

img = cv2.imread('test_images/test5.jpg') 



output = process_image(img)


plt.imshow(cv2.cvtColor(output, cv2.COLOR_BGR2RGB))

cv2.imwrite(
    "writeup_images/test5_output.jpg", 
    output
)
# Out:
# keeping current line position, max points is 17.500000000000004
# keeping current line position, max points is 7.600000000000001
# 161
# 1162
# True

# %%
from moviepy.editor import VideoFileClip
from IPython.display import HTML

white_output_challenge = 'project_video_output.mp4'

clip1 = VideoFileClip("project_video.mp4") #.subclip(1,3)

white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output_challenge, audio=False)
# Out:
# t:   0%|          | 2/1260 [00:00<01:35, 13.21it/s, now=None]
# keeping current line position, max points is 3.3000000000000007
# keeping current line position, max points is 13.100000000000001
# keeping current line position, max points is 10.8
# 308
# 1164
# Moviepy - Building video project_video_output.mp4.
# Moviepy - Writing video project_video_output.mp4
#
# keeping current line position, max points is 3.3000000000000007
# keeping current line position, max points is 13.100000000000001
# keeping current line position, max points is 10.8
# 308
# 1164
# t:   0%|          | 4/1260 [00:00<02:16,  9.23it/s, now=None]
# keeping current line position, max points is 4.6000000000000005
# keeping current line position, max points is 3.2000000000000006
# keeping current line position, max points is 8.5
# keeping current line position, max points is 18.7
# 309
# 1124
# keeping current line position, max points is 9.3
# 310
# 1179
# ...

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output_challenge))
# Out:
# <video width="960" height="540" controls>
#   <source src="project_video_output.mp4">
# </video>
